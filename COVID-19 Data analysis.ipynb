# %% [markdown]
# # Welcome to the project...

# %% [markdown]
# ### DATA is "same", "inference" makes the difference.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
corona_data_csv=pd.read_csv(r'E:\Mohit\Mohit Projects\COVID 19 data analysis using python\Dataset\covid19_Confirmed_dataset.csv')
corona_data_csv.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
corona_data_csv.shape
# Out:
# (266, 104)

# %%
# lets delete the useless columns
df = corona_data_csv.drop(['Lat','Long'],axis=1)
# axis=0 is used for the row deletion.
df.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
# lets delete the useless columns, but this time this will effet the main dataframe...
corona_data_csv.drop(['Lat','Long'],axis=1,inplace=True)
# axis=0 is used for the row deletion.
corona_data_csv.head(10)
# Out:
#                  Province/State       Country/Region  1/22/20  1/23/20  \
# 0                           NaN          Afghanistan        0        0
# 1                           NaN              Albania        0        0
# 2                           NaN              Algeria        0        0
# 3                           NaN              Andorra        0        0
# 4                           NaN               Angola        0        0
# 5                           NaN  Antigua and Barbuda        0        0
# 6                           NaN            Argentina        0        0
# 7                           NaN              Armenia        0        0
# 8  Australian Capital Territory            Australia        0        0
# 9               New South Wales            Australia        0        0
#
#    1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  1/29/20  ...  4/21/20  \
# 0        0        0        0        0        0        0  ...     1092
# ...

# %%
# aggregating all the rows with country region...\
corona_data_aggregated=corona_data_csv.groupby('Country/Region').sum()
corona_data_aggregated.head(10)
# Out:
#                      1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  \
# Country/Region
# Afghanistan                0        0        0        0        0        0
# Albania                    0        0        0        0        0        0
# Algeria                    0        0        0        0        0        0
# Andorra                    0        0        0        0        0        0
# Angola                     0        0        0        0        0        0
# Antigua and Barbuda        0        0        0        0        0        0
# Argentina                  0        0        0        0        0        0
# Armenia                    0        0        0        0        0        0
# Australia                  0        0        0        0        4        5
# Austria                    0        0        0        0        0        0
#
#                      1/28/20  1/29/20  1/30/20  1/31/20  ...  4/21/20  \
# Country/Region                                           ...
# ...

# %%
corona_data_aggregated.shape
# Out:
# (187, 100)

# %%
# data visualization...
corona_data_aggregated.loc['China'].plot()
corona_data_aggregated.loc['Italy'].plot()
#corona_data_aggregated.loc['India'].plot()
plt.legend()
# Out:
# c:\users\rohit\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)

# %%
corona_data_aggregated.loc['China'][:3].plot()
# Out:
# c:\users\rohit\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
# first derivate of the curve...
corona_data_aggregated.loc['China'].diff().plot()
# Out:
# c:\users\rohit\appdata\local\programs\python\python38-32\lib\site-packages\pandas\plotting\_matplotlib\core.py:1192: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xticklabels)
# <AxesSubplot:>

# %%
# maximum infected rate change day by day...
corona_data_aggregated.loc['China'].diff().max()
# this shows maximum increment in the no. of corona cases.
# Out:
# 15136.0

# %%
corona_data_aggregated.loc['Italy'].diff().max()
# Out:
# 6557.0

# %%
# lets find the maximum infection rate for all the countries...
countries = list(corona_data_aggregated.index)
maximum_infection_rates=[]
for country in countries:
    maximum_infection_rates.append(corona_data_aggregated.loc[country].diff().max())
maximum_infection_rates
# Out:
# [232.0,
#  34.0,
#  199.0,
#  43.0,
#  5.0,
#  6.0,
#  291.0,
#  134.0,
#  497.0,
#  1321.0,
#  105.0,
#  7.0,
#  301.0,
#  641.0,
#  12.0,
#  1485.0,
#  2454.0,
#  4.0,
#  19.0,
#  1.0,
#  104.0,
#  92.0,
#  7.0,
#  7502.0,
#  26.0,
#  137.0,
#  41.0,
#  21.0,
#  6.0,
#  45.0,
#  31.0,
#  203.0,
#  2778.0,
#  31.0,
#  21.0,
#  1138.0,
#  15136.0,
#  353.0,
#  1.0,
#  57.0,
#  81.0,
#  37.0,
#  113.0,
#  96.0,
#  63.0,
#  58.0,
#  381.0,
#  391.0,
#  99.0,
#  156.0,
#  5.0,
#  371.0,
#  11536.0,
#  269.0,
#  32.0,
#  130.0,
#  7.0,
#  134.0,
#  20.0,
#  9.0,
#  5.0,
#  267.0,
#  26849.0,
#  38.0,
#  5.0,
#  42.0,
#  6933.0,
#  403.0,
#  156.0,
#  6.0,
#  68.0,
#  167.0,
#  132.0,
#  12.0,
#  10.0,
#  3.0,
#  72.0,
#  210.0,
#  99.0,
#  1893.0,
#  436.0,
#  3186.0,
#  91.0,
#  1515.0,
#  1131.0,
#  6557.0,
#  52.0,
#  1161.0,
#  40.0,
#  264.0,
#  29.0,
#  851.0,
#  289.0,
#  300.0,
#  69.0,
#  3.0,
#  48.0,
#  61.0,
#  17.0,
#  13.0,
#  21.0,
#  90.0,
#  234.0,
#  7.0,
#  14.0,
# ...

# %%
corona_data_aggregated["maximum_infection_rate"]=maximum_infection_rates

# %%
corona_data_aggregated.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20  ...  4/22/20  4/23/20  4/24/20  \
# Country/Region                             ...
# Afghanistan           0        0        0  ...     1176     1279     1351
# Albania               0        0        0  ...      634      663      678
# Algeria               0        0        0  ...     2910     3007     3127
# Andorra               0        0        0  ...      723      723      731
# ...

# %%
# most important dataframe...
corona_data=pd.DataFrame(corona_data_aggregated['maximum_infection_rate'])
corona_data.head()
# Out:
#                 maximum_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0

# %%
# Lets analyse the world happiness report now...
happiness_report=pd.read_csv(r'E:\Mohit\Mohit Projects\COVID 19 data analysis using python\Dataset\worldwide_happiness_report.csv')
happiness_report.head()
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# 1                    0.996                         0.592       0.252
# 2                    1.028                         0.603       0.271
# 3                    1.026                         0.591       0.354
# 4                    0.999                         0.557       0.322
#
#    Perceptions of corruption
# 0                      0.393
# 1                      0.410
# ...

# %%
happiness_report.shape
# Out:
# (156, 9)

# %%
# drop the useless coulumns now...
useless_col=['Overall rank','Score','Generosity','Perceptions of corruption']
happiness_report.drop(useless_col,axis=1,inplace= True)
happiness_report.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0           Finland           1.340           1.587                    0.986
# 1           Denmark           1.383           1.573                    0.996
# 2            Norway           1.488           1.582                    1.028
# 3           Iceland           1.380           1.624                    1.026
# 4       Netherlands           1.396           1.522                    0.999
#
#    Freedom to make life choices
# 0                         0.596
# 1                         0.592
# 2                         0.603
# 3                         0.591
# 4                         0.557

# %%
happiness_report.shape
# Out:
# (156, 5)

# %%
#df= happiness_report.groupby(['Country or region'])
#df.head()
happiness_report.set_index("Country or region",inplace= True)
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report.shape
# Out:
# (156, 4)

# %% [markdown]
# ## let's join the datasets to derive a inference...

# %%
corona_data.head()
# Out:
#                 maximum_infection_rate
# Country/Region
# Afghanistan                      232.0
# Albania                           34.0
# Algeria                          199.0
# Andorra                           43.0
# Angola                             5.0

# %%
corona_data.shape
# Out:
# (187, 1)

# %%
happiness_report.head()
# Out:
#                    GDP per capita  Social support  Healthy life expectancy  \
# Country or region
# Finland                     1.340           1.587                    0.986
# Denmark                     1.383           1.573                    0.996
# Norway                      1.488           1.582                    1.028
# Iceland                     1.380           1.624                    1.026
# Netherlands                 1.396           1.522                    0.999
#
#                    Freedom to make life choices
# Country or region
# Finland                                   0.596
# Denmark                                   0.592
# Norway                                    0.603
# Iceland                                   0.591
# Netherlands                               0.557

# %%
happiness_report.shape
# Out:
# (156, 4)

# %%
# number of countries are varying in both the datasets are different, so let's use inner join...
data=corona_data.join(happiness_report,how='inner')
data.head()
# Out:
#              maximum_infection_rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
data.shape
# Out:
# (143, 5)

# %%
# correlation matrix

data.corr()

# Amazing thing is we see positive correlation between various coefficients.
# Out:
#                               maximum_infection_rate  GDP per capita  \
# maximum_infection_rate                      1.000000        0.250118
# GDP per capita                              0.250118        1.000000
# Social support                              0.191958        0.759468
# Healthy life expectancy                     0.289263        0.863062
# Freedom to make life choices                0.078196        0.394603
#
#                               Social support  Healthy life expectancy  \
# maximum_infection_rate              0.191958                 0.289263
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# Freedom to make life choices        0.456246                 0.427892
#
#                               Freedom to make life choices
# maximum_infection_rate                            0.078196
# ...

# %% [markdown]
# ### Most important..... Visualizaion......

# %%
data.head()
# Out:
#              maximum_infection_rate  GDP per capita  Social support  \
# Afghanistan                   232.0           0.350           0.517
# Albania                        34.0           0.947           0.848
# Algeria                       199.0           1.002           1.160
# Argentina                     291.0           1.092           1.432
# Armenia                       134.0           0.850           1.055
#
#              Healthy life expectancy  Freedom to make life choices
# Afghanistan                    0.361                         0.000
# Albania                        0.874                         0.383
# Algeria                        0.785                         0.086
# Argentina                      0.881                         0.471
# Armenia                        0.815                         0.283

# %%
# GDP vs maxmaximum_infection_rate

x= data['GDP per capita']
y= data['maximum_infection_rate']
sns.scatterplot(x,y)
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='maximum_infection_rate'>

# %% [markdown]
# #### The above groaph is not clearly visible because the variation in units of x and y

# %%
# GDP vs maxmaximum_infection_rate

x= data['GDP per capita']
y= data['maximum_infection_rate']
sns.scatterplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='maximum_infection_rate'>

# %%
# lets fit a curve in the dataset...
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='GDP per capita', ylabel='maximum_infection_rate'>

# %%
# Social support vs maxmaximum_infection_rate

x= data['Social support']
y= data['maximum_infection_rate']
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Social support', ylabel='maximum_infection_rate'>

# %%
# Healthy life expectancy vs maxmaximum_infection_rate

x= data['Healthy life expectancy']
y= data['maximum_infection_rate']
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Healthy life expectancy', ylabel='maximum_infection_rate'>

# %%
# Freedom to make life choices vs maxmaximum_infection_rate

x= data['Freedom to make life choices']
y= data['maximum_infection_rate']
sns.regplot(x,np.log(y))
# Out:
# <AxesSubplot:xlabel='Freedom to make life choices', ylabel='maximum_infection_rate'>

# %% [markdown]
# This can clearly be visualized that the factors where we become __more happy__ certainly being in more developed nation takes us to higher risk side of being affected from the __corona virus__
